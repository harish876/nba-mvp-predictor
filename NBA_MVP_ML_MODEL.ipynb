# %% [markdown]
# <a href="https://colab.research.google.com/github/harish876/nba-mvp-predictor/blob/main/NBA_MVP_ML_MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pms=pd.read_csv("/content/drive/MyDrive/nba_mvp_data/player_mvp_data.csv")

# %%
del pms["Unnamed: 0"]

# %%
pms.head()
# Out:
#            Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  Pts Max  \
# 0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...      0.0
# 1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...      0.0
# 2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...      0.0
# 3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...      0.0
# 4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...      0.0
#
#    Share                Team   W   L   W/L%   GB   PS/G  PA/G   SRS
# 0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3  99.6  6.73
# 1    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3  99.6  6.73
# 2    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3  99.6  6.73
# 3    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3  99.6  6.73
# 4    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3  99.6  6.73
#
# [5 rows x 41 columns]

# %%
pms.isnull().sum()
# Out:
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%          50
# 3P            0
# 3PA           0
# 3P%        2042
# 2P            0
# 2PA           0
# 2P%          84
# eFG%         50
# FT            0
# FTA           0
# FT%         462
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Year          0
# Pts Won       0
# Pts Max       0
# Share         0
# Team          0
# W             0
# L             0
# W/L%          0
# GB            0
# PS/G          0
# PA/G          0
# SRS           0
# dtype: int64

# %%
pms[pms.isnull()["3P%"]][["Player","3PA"]]
# Out:
#                  Player  3PA
# 2        Elden Campbell  0.0
# 3         Irving Thomas  0.0
# 18           Jack Haley  0.0
# 20          Keith Owens  0.0
# 30      Benoit Benjamin  0.0
# ...                 ...  ...
# 14061    Evan Eschmeyer  0.0
# 14062  Gheorghe Mureșan  0.0
# 14064     Jim McIlvaine  0.0
# 14070  Mark Hendrickson  0.0
# 14071      Michael Cage  0.0
#
# [2042 rows x 2 columns]

# %%
pms=pms.fillna(0)

# %%
pms.isnull().sum()

# %%
pms.columns

# %%
predictors=['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
       '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
        'W', 'L', 'W/L%', 'GB', 'PS/G',
       'PA/G', 'SRS']

# %%
train=pms[pms["Year"]<2021]
test=pms[pms["Year"]==2021]

# %%
from sklearn.linear_model import Ridge

# %%
reg=Ridge(alpha=.1)

# %%
reg.fit(train[predictors],train["Share"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions=reg.predict(test[predictors])

# %%
predictions=pd.DataFrame(predictions,columns=["predictions"],index=test.index)

# %%
combination=pd.concat([test[["Player","Share"]],predictions],axis=1)

# %%
combination=combination.sort_values("Share",ascending=False)
combination["Rk"]=list(range(1,combination.shape[0]+1))

# %%
combination
# Out:
#                       Player  Share  predictions   Rk
# 641             Nikola Jokić  0.961     0.154306    1
# 8624             Joel Embiid  0.580     0.162713    2
# 3651           Stephen Curry  0.449     0.142386    3
# 9907   Giannis Antetokounmpo  0.345     0.207436    4
# 1389              Chris Paul  0.138     0.072293    5
# ...                      ...    ...          ...  ...
# 4171           Chris Chiozza  0.000     0.007047  536
# 4170             Bruce Brown  0.000     0.003655  537
# 4169           Blake Griffin  0.000     0.011745  538
# 4168          Andre Roberson  0.000    -0.026907  539
# 13901             Trey Lyles  0.000    -0.005421  540
#
# [540 rows x 4 columns]

# %%
combination=combination.sort_values("predictions",ascending=False)
combination["predicted_Rk"]=list(range(1,combination.shape[0]+1))

# %%
combination
# Out:
#                       Player  Share  predictions   Rk  predicted_Rk
# 9907   Giannis Antetokounmpo  0.345     0.207436    4             1
# 8624             Joel Embiid  0.580     0.162713    2             2
# 641             Nikola Jokić  0.961     0.154306    1             3
# 10997            Luka Dončić  0.042     0.151430    6             4
# 3736            LeBron James  0.001     0.147512   15             5
# ...                      ...    ...          ...  ...           ...
# 9437           Patrick McCaw  0.000    -0.050344  113           536
# 13476          Killian Hayes  0.000    -0.051316  200           537
# 9915             P.J. Tucker  0.000    -0.054995   33           538
# 3862        Anžejs Pasečņiks  0.000    -0.062399  489           539
# 11768           Didi Louzada  0.000    -0.069542  267           540
#
# [540 rows x 5 columns]

# %%
actual=combination.sort_values("Share",ascending=False).head(5)
actual
# Out:
#                      Player  Share  predictions  Rk  predicted_Rk
# 641            Nikola Jokić  0.961     0.154306   1             3
# 8624            Joel Embiid  0.580     0.162713   2             2
# 3651          Stephen Curry  0.449     0.142386   3             6
# 9907  Giannis Antetokounmpo  0.345     0.207436   4             1
# 1389             Chris Paul  0.138     0.072293   5            33

# %%
predicted=combination.sort_values("predictions",ascending=False)
predicted.head(35)
# Out:
#                         Player  Share  predictions   Rk  predicted_Rk
# 9907     Giannis Antetokounmpo  0.345     0.207436    4             1
# 8624               Joel Embiid  0.580     0.162713    2             2
# 641               Nikola Jokić  0.961     0.154306    1             3
# 10997              Luka Dončić  0.042     0.151430    6             4
# 3736              LeBron James  0.001     0.147512   15             5
# 3651             Stephen Curry  0.449     0.142386    3             6
# 4177              Kevin Durant  0.000     0.141350  531             7
# 4174              James Harden  0.001     0.140598   13             8
# 11784          Zion Williamson  0.000     0.127926  251             9
# 3876         Russell Westbrook  0.005     0.120227   11            10
# 6093              Jimmy Butler  0.000     0.117102  442            11
# 7464            Damian Lillard  0.038     0.116303    7            12
# ...

# %%
#do not understand error metric
def actual_ap(combination):
  actual=combination.sort_values("Share",ascending=False).head(5)
  predicted=combination.sort_values("predictions",ascending=False)
  ps=[]
  found=0
  seen=1
  for index,row in predicted.iterrows():
    if row["Player"] in actual["Player"].values:
      found+=1
      ps.append(found/seen)
    seen+=1
  return sum(ps)/len(ps)

# %%
actual_ap(combination)
# Out:
# 0.7636363636363636

# %%
years=list(range(1991,2022))

# %%
#finding the ap for the all years
aps=[]
all_predictions=[]
for year in years[5:]:
  train=pms[pms["Year"]<year]
  test=pms[pms["Year"]==year]
  reg.fit(train[predictors],train["Share"])
  predictions=reg.predict(test[predictors])
  predictions=pd.DataFrame(predictions,columns=["predictions"],index=test.index)
  combination=pd.concat([test[["Player","Share"]],predictions],axis=1)
  all_predictions.append(combination)
  aps.append(actual_ap(combination))

# %%
sum(aps)/len(aps)
# Out:
# 0.7112884360789578

# %%
def add_rank(combination):
  combination=combination.sort_values("Share",ascending=False)
  combination["Rk"]=list(range(1,combination.shape[0]+1))
  combination=combination.sort_values("predictions",ascending=False)
  combination["predicted_Rk"]=list(range(1,combination.shape[0]+1))
  combination["Difference"]=combination["Rk"]-combination["predicted_Rk"]
  return combination

# %%
ranking=add_rank(all_predictions[1])
ranking[ranking["Rk"]<6].sort_values("Difference",ascending=False)
# Out:
#                Player  Share  predictions  Rk  predicted_Rk  Difference
# 1600      Karl Malone  0.857     0.192318   1             2          -1
# 10524  Michael Jordan  0.832     0.167629   2             3          -1
# 908        Grant Hill  0.327     0.128646   3             6          -3
# 4682     Tim Hardaway  0.207     0.059984   4            20         -16
# 8248        Glen Rice  0.117     0.033110   5            53         -48

# %%
years=list(range(1991,2022))
def backtest(pms,model,years,predictors):
  aps=[]
  all_predictions=[]
  for year in years:
    train=pms[pms["Year"]<year]
    test=pms[pms["Year"]==year]
    model.fit(train[predictors],train["Share"])
    predictions=model.predict(test[predictors])
    predictions=pd.DataFrame(predictions,columns=["predictions"],index=test.index)
    combination=pd.concat([test[["Player","Share"]],predictions],axis=1)
    combination=add_rank(combination)
    all_predictions.append(combination)
    aps.append(actual_ap(combination))
  return sum(aps)/len(aps),aps,pd.concat(all_predictions)

# %%
mean_ap,aps,all_predictions_list=backtest(pms,reg,years[5:],predictors)

# %%
mean_ap
# Out:
# 0.7112884360789578

# %%
aps
# Out:
# [0.47000000000000003,
#  0.3922012578616352,
#  0.8102564102564103,
#  0.3871428571428571,
#  0.8392857142857142,
#  0.9266666666666665,
#  0.6835164835164835,
#  0.9666666666666666,
#  0.6906015037593984,
#  0.5644444444444445,
#  0.4071008403361344,
#  0.6476190476190476,
#  0.7683333333333333,
#  0.9428571428571428,
#  0.8142857142857143,
#  0.7392857142857142,
#  0.40535714285714286,
#  0.6976190476190476,
#  0.6341698841698842,
#  0.9266666666666665,
#  0.8333333333333333,
#  0.8111111111111111,
#  0.7909090909090909,
#  0.6375757575757576,
#  0.9428571428571428,
#  0.7636363636363636]
